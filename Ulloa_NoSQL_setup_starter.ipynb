# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
for dbname in mongo.list_database_names():
    print(dbname, "<------------------" if dbname=='uk_food' else "")
# Out:
# admin
# classDB
# config
# epa
# fruits_db
# local
# met
# travel_db
# uk_food <------------------

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %%
# review a document in the establishments collection
pprint(establishments.find_one())
# Out:
# {'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'The Coastguard Inn',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4587.347174863443,
#  'FHRSID': 1034540,
#  'LocalAuthorityBusinessID': 'PI/000078691',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DY',
#  'RatingDate': '2022-08-17T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65694a51cca46f7b69a1872b'),
#  'geocode': {'latitude': '51.152225', 'longitude': '1.387974'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1034540',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_halal_restaurant = {
                        "BusinessName": "Penang Flavours",
                        "BusinessType": "Restaurant/Cafe/Canteen",
                        "BusinessTypeID": " ",
                        "AddressLine1": "Penang Flavours",
                        "AddressLine2": "146A Plumstead Rd",
                        "AddressLine3": "London",
                        "AddressLine4": " ",
                        "PostCode": "SE18 7DY",
                        "Phone": " ",
                        "LocalAuthorityCode": "511",
                        "LocalAuthorityName": "Greenwich",
                        "LocalAuthorityWebsite": "http://www.royalgreenwich.gov.uk",
                        "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
                        "scores":{
                            "Hygiene":"",
                            "Structural":"",
                            "ConfidenceInManagement":""
                            },
                        "SchemeType":"FHRS",
                        "geocode":{
                            "longitude":"0.08384000",
                            "latitude":"51.49014200"
                            },
                        "RightToReply":"",
                        "Distance":4623.9723280747176,
                        "NewRatingPending":True
                       }

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_halal_restaurant)

# %%
# Check that the new restaurant was inserted
pprint(establishments.find_one({'BusinessName':'Penang Flavours'}))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': ' ',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': ' ',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebsite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': ' ',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65694a84f4c2797695e832e4'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {'BusinessType': "Restaurant/Cafe/Canteen"}
fields = {'BusinessTypeID':1, 'BusinessType':1}

# Capture the results to a variable
results = establishments.find(query,fields)

# PrettyPrint the results
for result in results:
    pprint(result)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1872d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1872f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18730')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18731')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18732')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18733')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18734')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18738')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18739')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1873b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1873e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1873f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18746')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18749')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18750')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1875b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1875d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1875f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18762')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18763')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18767')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18768')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1876a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1876b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1876d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1876e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18773')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18774')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18777')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18778')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1877a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1877d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18781')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18782')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18784')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1878e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18790')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18791')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18796')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18797')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18798')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1879c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1879d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187a1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187a2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187ab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187ad')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187b0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187b4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187b5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187b8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187b9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187bb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187bf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187c5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187d3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187d4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187d7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187d9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187da')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187dd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187e4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187e5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187e9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187ec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187f3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187f5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a187f7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18800')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18802')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18806')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1880a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18814')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18817')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18819')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18825')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18827')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18828')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1882a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1882d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1883b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1883c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18840')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18842')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18847')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18849')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1884b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18853')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1885f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18860')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18863')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18864')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18865')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18869')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1886c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1886f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18874')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18875')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18877')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18878')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18879')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1887b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1887c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1887d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1887f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18882')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18885')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18889')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1888b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18890')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18897')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1889b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1889c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1889e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188a2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188a4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188a6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188a8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188aa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188af')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188b0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188b3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188b4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188b6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188c2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188c3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188c5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188d0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188d1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188d2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188d6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188d7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188df')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188e2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188ee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188f0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188f3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188f4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188f8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188fb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a188fc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1890d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18919')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18920')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18924')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1894b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1894d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18950')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18954')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18956')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1895d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a1896e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18978')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18990')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18993')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a189a2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a189a4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a189a5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a189ad')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a189b6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a189c1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a189c2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a189c9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a189ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a189cf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a189d4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a189d5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a189d7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a189db')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a189df')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a189e0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a189ee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a189f1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a189f2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a189f5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a00')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a07')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a09')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a10')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a15')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a1a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a22')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a25')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a31')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a32')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a3a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a3c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a40')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a42')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a46')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a47')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a57')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a5d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a60')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a66')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a69')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a6a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a6d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a70')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a72')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a75')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a76')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a78')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a79')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a7f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a80')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a82')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a85')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a88')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a89')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a8a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a8f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a90')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a99')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a9a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18a9c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18aa0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18aa4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18aa6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18aa9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18aab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18aaf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ab0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ab2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ab5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ab9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18aba')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18abb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18abe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ac4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ac5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ac8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18acb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18acc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18acf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ad7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ad9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18add')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ae0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ae1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ae2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18aeb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18aed')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18af0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18af5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18af8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18af9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18afa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18afb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18afc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18aff')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b00')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b04')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b05')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b06')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b0d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b18')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b19')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b1b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b1d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b1e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b22')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b24')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b25')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b27')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b29')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b2c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b2f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b32')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b34')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b37')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b3e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b48')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b4f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b5e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b61')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b64')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b6b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b6e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b72')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b75')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b89')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b93')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b94')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b95')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b98')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18b9c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ba2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ba6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ba7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ba8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ba9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18baa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bad')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bae')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18baf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bb0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bb1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bb8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bc1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bc8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bc9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bcc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bcd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bd0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bd1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bd3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bd4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bd6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bdc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bdd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18be0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18be6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18be7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18be9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bf0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bf7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bfa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bfd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18bff')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c00')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c02')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c03')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c05')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c0e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c12')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c13')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c18')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c1b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c1f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c21')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c23')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c26')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c2e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c33')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c3a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c3f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c42')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c47')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c4a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c4b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c4d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c53')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c5a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c5d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c5e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c5f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c61')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c65')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c6a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c6d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c6f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c71')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c7a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c7b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c7c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c7f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c82')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c84')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c85')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c86')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c87')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c89')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c8b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c8c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c8d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c8e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c92')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c93')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c94')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c95')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c98')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c99')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c9a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c9d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18c9e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ca0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ca1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ca2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ca6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ca8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18cac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18cb0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18cb2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18cb3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18cb5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18cb6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18cb7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18cb9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18cbe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18cbf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18cc2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18cc4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18cc7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ccd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18cd0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18cd7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18cd9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ce4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18ced')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18cfc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18cff')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18d02')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18d08')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18d0b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18d10')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18d11')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18d17')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18d19')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18d1d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18d1e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18d1f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18d22')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18d26')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18d2c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18d2d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18d39')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18d3a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18d41')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a51cca46f7b69a18d43')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
# ...
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22079')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2207b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2207c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2207d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22083')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22086')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22087')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22088')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2208d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2208f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22091')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22099')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2209b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2209c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220a0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220a3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220a4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220a5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220a7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220a8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220a9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220ab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220ae')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220af')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220b0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220b1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220b5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220b6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220b7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220b8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220be')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220c4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220c5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220c8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220ca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220cb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220cd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220cf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220de')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220e0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220e7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220e8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220ea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220f3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220f4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220f5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a220fe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22123')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22127')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2212b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22131')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22132')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22134')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22137')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22138')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2213b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2213c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2213d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2213e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22141')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2214e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22152')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22161')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22162')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22167')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2216d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22177')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22179')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2217a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2217e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22180')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22181')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22182')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22184')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2218c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2219b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2219f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221b0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221b1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221b7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221bc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221bd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221c0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221c8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221c9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221cb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221d1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221da')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221de')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221df')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221e2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221e4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221e5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221e6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221e9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221eb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221ec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221ee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221ef')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221f3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221f4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221f5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221f6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221f7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221f8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221fb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221fc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221fd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a221fe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22201')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22206')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22207')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2220c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2220e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22210')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22211')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22215')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2221b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22221')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22228')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2222a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22230')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22231')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22234')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22239')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2223b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22249')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22250')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2225a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22265')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22268')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2226f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22271')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22275')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2227a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2227c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a22281')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65694a5ccca46f7b69a2228b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': ' ',
#  '_id': ObjectId('65694a84f4c2797695e832e4')}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one(
                {'BusinessName':'Penang Flavours'},
                        {'$set':
                            {'BusinessTypeID': 1}
                        }
)

# %%
# Confirm that the new restaurant was updated
pprint(establishments.find_one({'BusinessName':'Penang Flavours'}))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': ' ',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebsite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': ' ',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65694a84f4c2797695e832e4'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {'LocalAuthorityName':{'$regex':'Dover','$options': "i"}}
print("Number of establishments in Dover:", establishments.count_documents(query))
# Out:
# Number of establishments in Dover: 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many(query)
results = establishments.find(query)
for result in results:
    print(result)

# %%
# Check if any remaining documents include Dover
print("Number of establishments in Dover:", establishments.count_documents(query))
# Out:
# Number of establishments in Dover: 0

# %%
# Check that other documents remain with 'find_one'
still_here = db.establishments.find_one()
pprint(still_here)
# Out:
# {'AddressLine1': 'St Marys Church Of England Primary School',
#  'AddressLine2': 'Warren Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'St Marys COE (aided) Primary School',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'ChangesByServerID': 0,
#  'Distance': 4591.871474174837,
#  'FHRSID': 289353,
#  'LocalAuthorityBusinessID': 'PI/000002468',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6QH',
#  'RatingDate': '2016-09-13T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65694a51cca46f7b69a18a11'),
#  'geocode': {'latitude': '51.085797', 'longitude': '1.194762'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/289353',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, [{'$set':{'geocode.latitude':{'$toDecimal':'$geocode.latitude'},
                                         'geocode.longitude':{'$toDecimal':'$geocode.longitude'}
                                        }
                                }
                               ]
                          )

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [{'$set':{
                                    'RatingValue':{
                                        '$toInt':"$RatingValue"
                                                }
                                        }
                                }
                               ]
                          )

# %%
# Check that the coordinates are now numbers
[est for est in establishments.find({}, ['geocode.longitude', 'geocode.latitude','RatingValue'])]
# Out:
# [{'_id': ObjectId('65694a51cca46f7b69a18a11'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.194762'),
#    'latitude': Decimal128('51.085797')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a12'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.196408'),
#    'latitude': Decimal128('51.086058')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a15'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.195625'),
#    'latitude': Decimal128('51.083812')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a17'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.188537'),
#    'latitude': Decimal128('51.08084')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a18'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.188537'),
#    'latitude': Decimal128('51.08084')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a19'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a1a'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a1b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a1c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a1d'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.188537'),
#    'latitude': Decimal128('51.08084')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a1e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a1f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a20'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a21'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a22'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a23'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a24'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a25'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a26'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a27'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a28'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a29'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a2a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a2b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a2c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a2d'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a2e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a2f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.188537'),
#    'latitude': Decimal128('51.08084')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a30'),
#   'RatingValue': 2,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a31'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a32'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a33'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a34'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a35'),
#   'RatingValue': 2,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a36'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a37'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a38'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a39'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a3a'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a3b'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a3c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a3d'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a3e'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.18794649942731'),
#    'latitude': Decimal128('51.0805695006979')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a3f'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.18590330311705'),
#    'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a40'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.202055'),
#    'latitude': Decimal128('51.095015')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a41'),
#   'RatingValue': 2,
#   'geocode': {'longitude': Decimal128('1.18516'),
#    'latitude': Decimal128('51.078449')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a42'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.187083'),
#    'latitude': Decimal128('51.080673')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a43'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.186825'),
#    'latitude': Decimal128('51.080446')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a44'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18628335007084'),
#    'latitude': Decimal128('51.079985650005')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a46'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.186485'),
#    'latitude': Decimal128('51.080284')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a47'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.186485'),
#    'latitude': Decimal128('51.080284')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a4a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.194306'),
#    'latitude': Decimal128('51.087887')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a4b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.185368'),
#    'latitude': Decimal128('51.079613')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a4c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.186067'),
#    'latitude': Decimal128('51.080224')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a4d'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.183585'),
#    'latitude': Decimal128('51.077971')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a4e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.188902'),
#    'latitude': Decimal128('51.083232')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a50'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.186309'),
#    'latitude': Decimal128('51.080838')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a51'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.187056'),
#    'latitude': Decimal128('51.081735')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a52'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.185368'),
#    'latitude': Decimal128('51.079613')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a53'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.186715'),
#    'latitude': Decimal128('51.081546')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a54'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.184194'),
#    'latitude': Decimal128('51.07915')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a55'),
#   'RatingValue': 2,
#   'geocode': {'longitude': Decimal128('1.184194'),
#    'latitude': Decimal128('51.07915')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a57'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.184916'),
#    'latitude': Decimal128('51.0803')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a5a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1920251'),
#    'latitude': Decimal128('51.0877821')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a5b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18601894378662'),
#    'latitude': Decimal128('51.0818061828613')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a5d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18425798416138'),
#    'latitude': Decimal128('51.0804748535156')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a5e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.190896'),
#    'latitude': Decimal128('51.086262')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a5f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18421399593353'),
#    'latitude': Decimal128('51.0804824829102')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a60'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18421399593353'),
#    'latitude': Decimal128('51.0804824829102')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a61'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.18431901931763'),
#    'latitude': Decimal128('51.0809478759766')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a62'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.18429'),
#    'latitude': Decimal128('51.080956')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a63'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182962'),
#    'latitude': Decimal128('51.0793')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a64'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.182962'),
#    'latitude': Decimal128('51.079301')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a65'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18429'),
#    'latitude': Decimal128('51.080956')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a66'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18429'),
#    'latitude': Decimal128('51.080956')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a67'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.201433'),
#    'latitude': Decimal128('51.097794')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a68'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.19522100055125'),
#    'latitude': Decimal128('51.0917365039471')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a69'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.183893'),
#    'latitude': Decimal128('51.080804')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a6a'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.183894'),
#    'latitude': Decimal128('51.080805')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a6b'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.18429'),
#    'latitude': Decimal128('51.080956')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a6c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182875'),
#    'latitude': Decimal128('51.079905')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a6d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182805'),
#    'latitude': Decimal128('51.080339')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a6e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182805'),
#    'latitude': Decimal128('51.080339')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a6f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182805'),
#    'latitude': Decimal128('51.08034')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a70'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182805'),
#    'latitude': Decimal128('51.08034')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a71'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182805'),
#    'latitude': Decimal128('51.08034')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a72'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182805'),
#    'latitude': Decimal128('51.08034')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a74'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1835476'),
#    'latitude': Decimal128('51.0810258')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a75'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.181832'),
#    'latitude': Decimal128('51.079889')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a76'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1823865'),
#    'latitude': Decimal128('51.0802956')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a77'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.181365'),
#    'latitude': Decimal128('51.079542')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a78'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.1822069'),
#    'latitude': Decimal128('51.0803409')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a79'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1813759803772'),
#    'latitude': Decimal128('51.079532623291')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a7a'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.181365'),
#    'latitude': Decimal128('51.079542')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a7b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1817077'),
#    'latitude': Decimal128('51.0798931')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a7c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182125'),
#    'latitude': Decimal128('51.080412')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a7d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.181365'),
#    'latitude': Decimal128('51.079542')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a7e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182125'),
#    'latitude': Decimal128('51.080412')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a7f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.181482'),
#    'latitude': Decimal128('51.079799')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a80'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1813097'),
#    'latitude': Decimal128('51.0800235')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a81'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1814856'),
#    'latitude': Decimal128('51.0802346')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a82'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.179446'),
#    'latitude': Decimal128('51.078209')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a83'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1810166'),
#    'latitude': Decimal128('51.0797886')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a84'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.181483'),
#    'latitude': Decimal128('51.0798')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a85'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.18172800540924'),
#    'latitude': Decimal128('51.0806732177734')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a86'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.190904'),
#    'latitude': Decimal128('51.089491')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a87'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.181728'),
#    'latitude': Decimal128('51.080675')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a88'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.181728'),
#    'latitude': Decimal128('51.080675')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a89'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.181728'),
#    'latitude': Decimal128('51.080675')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a8a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.181728'),
#    'latitude': Decimal128('51.080675')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a8b'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.181728'),
#    'latitude': Decimal128('51.080675')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a8c'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.181728'),
#    'latitude': Decimal128('51.080675')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a8d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.190904'),
#    'latitude': Decimal128('51.089491')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a8e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182609'),
#    'latitude': Decimal128('51.08164')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a8f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182609'),
#    'latitude': Decimal128('51.08164')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a90'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1802781'),
#    'latitude': Decimal128('51.0793698')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a91'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.185011'),
#    'latitude': Decimal128('51.083976')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a92'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.180437'),
#    'latitude': Decimal128('51.07954')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a93'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.180437'),
#    'latitude': Decimal128('51.07954')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a94'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.180437'),
#    'latitude': Decimal128('51.07954')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a95'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.183327'),
#    'latitude': Decimal128('51.082322')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a96'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1817227'),
#    'latitude': Decimal128('51.0806941')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a97'),
#   'RatingValue': 2,
#   'geocode': {'longitude': Decimal128('1.185748'),
#    'latitude': Decimal128('51.084721')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a98'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.1826116'),
#    'latitude': Decimal128('51.0816612')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a99'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.18279695510864'),
#    'latitude': Decimal128('51.0818634033203')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a9a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.181282'),
#    'latitude': Decimal128('51.080417')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a9b'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.181282'),
#    'latitude': Decimal128('51.080417')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a9c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18128204345703'),
#    'latitude': Decimal128('51.0804176330566')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a9d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.181023'),
#    'latitude': Decimal128('51.080181')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a9e'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.180437'),
#    'latitude': Decimal128('51.07954')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18a9f'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.185748'),
#    'latitude': Decimal128('51.08472')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aa0'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182356'),
#    'latitude': Decimal128('51.081494')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aa1'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182753'),
#    'latitude': Decimal128('51.08187')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aa2'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.178909'),
#    'latitude': Decimal128('51.078296')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aa3'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.178909'),
#    'latitude': Decimal128('51.078296')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aa4'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182753'),
#    'latitude': Decimal128('51.08187')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aa5'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.182753'),
#    'latitude': Decimal128('51.08187')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aa6'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.178909'),
#    'latitude': Decimal128('51.078296')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aa7'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.186241'),
#    'latitude': Decimal128('51.085454')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aa8'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.186977'),
#    'latitude': Decimal128('51.086189')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aa9'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.178909'),
#    'latitude': Decimal128('51.078296')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aaa'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.186977'),
#    'latitude': Decimal128('51.086189')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aab'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.17911505699158'),
#    'latitude': Decimal128('51.0785865783691')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aac'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.179115'),
#    'latitude': Decimal128('51.078587')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aad'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.1803396'),
#    'latitude': Decimal128('51.0798709')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aae'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1785097'),
#    'latitude': Decimal128('51.0780695')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aaf'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1806797'),
#    'latitude': Decimal128('51.0802287')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ab0'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.1783613'),
#    'latitude': Decimal128('51.0781968')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ab1'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.1783613'),
#    'latitude': Decimal128('51.0781968')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ab2'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1784815'),
#    'latitude': Decimal128('51.078117')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ab3'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.179729'),
#    'latitude': Decimal128('51.079632')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ab4'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.183784'),
#    'latitude': Decimal128('51.083569')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ab5'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.179729'),
#    'latitude': Decimal128('51.079632')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ab6'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.183784'),
#    'latitude': Decimal128('51.083569')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ab7'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18039'),
#    'latitude': Decimal128('51.080315')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ab8'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1818685'),
#    'latitude': Decimal128('51.0818613')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ab9'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1818685'),
#    'latitude': Decimal128('51.0818613')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aba'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18039'),
#    'latitude': Decimal128('51.080315')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18abb'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.178027'),
#    'latitude': Decimal128('51.078131')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18abd'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.179926'),
#    'latitude': Decimal128('51.080211')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18abe'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.179926'),
#    'latitude': Decimal128('51.080211')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18abf'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.179925'),
#    'latitude': Decimal128('51.080211')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ac1'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.181201'),
#    'latitude': Decimal128('51.081526')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ac2'),
#   'RatingValue': 1,
#   'geocode': {'longitude': Decimal128('1.1799178'),
#    'latitude': Decimal128('51.080217')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ac3'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.178961'),
#    'latitude': Decimal128('51.079481')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ac4'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.178962'),
#    'latitude': Decimal128('51.079482')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ac5'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.178962'),
#    'latitude': Decimal128('51.079482')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ac6'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.180846'),
#    'latitude': Decimal128('51.081337')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ac7'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.180846'),
#    'latitude': Decimal128('51.081337')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ac8'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17884'),
#    'latitude': Decimal128('51.079161')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ac9'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.177752'),
#    'latitude': Decimal128('51.0783483')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aca'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.188295'),
#    'latitude': Decimal128('51.088735')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18acb'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.1817418'),
#    'latitude': Decimal128('51.0824157')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18acc'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1776046'),
#    'latitude': Decimal128('51.0783433')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18acd'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.188295'),
#    'latitude': Decimal128('51.088735')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ace'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.177468'),
#    'latitude': Decimal128('51.078317')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18acf'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.177468'),
#    'latitude': Decimal128('51.078317')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ad0'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.177468'),
#    'latitude': Decimal128('51.078317')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ad3'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.177468'),
#    'latitude': Decimal128('51.078317')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ad4'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182136'),
#    'latitude': Decimal128('51.082867')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ad5'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.186371'),
#    'latitude': Decimal128('51.087132')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ad6'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1796215'),
#    'latitude': Decimal128('51.0806446')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ad7'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.179629'),
#    'latitude': Decimal128('51.080669')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ad8'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.179629'),
#    'latitude': Decimal128('51.080669')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ad9'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.179628'),
#    'latitude': Decimal128('51.080668')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ada'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.182136'),
#    'latitude': Decimal128('51.082867')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18adb'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.181896'),
#    'latitude': Decimal128('51.083108')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18adc'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.175486'),
#    'latitude': Decimal128('51.076896')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18add'),
#   'RatingValue': 2,
#   'geocode': {'longitude': Decimal128('1.1794011'),
#    'latitude': Decimal128('51.0804496')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ade'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17673301696777'),
#    'latitude': Decimal128('51.0782127380371')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18adf'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.176733'),
#    'latitude': Decimal128('51.078211')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ae0'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.177506'),
#    'latitude': Decimal128('51.079081')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ae1'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.178969'),
#    'latitude': Decimal128('51.080624')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ae2'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17799'),
#    'latitude': Decimal128('51.079679')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ae3'),
#   'RatingValue': 2,
#   'geocode': {'longitude': Decimal128('1.1794486'),
#    'latitude': Decimal128('51.0808513')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ae4'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.177506'),
#    'latitude': Decimal128('51.079081')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ae5'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17957198619843'),
#    'latitude': Decimal128('51.0810699462891')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ae6'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17799'),
#    'latitude': Decimal128('51.079679')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ae7'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.17799'),
#    'latitude': Decimal128('51.079679')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ae8'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17799'),
#    'latitude': Decimal128('51.079679')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18ae9'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.174813'),
#    'latitude': Decimal128('51.076653')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aea'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.17575001716614'),
#    'latitude': Decimal128('51.0776252746582')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aeb'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17575'),
#    'latitude': Decimal128('51.077626')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aec'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.17575'),
#    'latitude': Decimal128('51.077626')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aed'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.17575'),
#    'latitude': Decimal128('51.077626')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aee'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.17575'),
#    'latitude': Decimal128('51.077626')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aef'),
#   'RatingValue': 1,
#   'geocode': {'longitude': Decimal128('1.185418'),
#    'latitude': Decimal128('51.087185')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18af0'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17352676391602'),
#    'latitude': Decimal128('51.0758056640625')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18af1'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1753663'),
#    'latitude': Decimal128('51.0776458')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18af2'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.174605'),
#    'latitude': Decimal128('51.076956')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18af3'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.174605'),
#    'latitude': Decimal128('51.076956')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18af4'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.176296'),
#    'latitude': Decimal128('51.078718')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18af5'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.17575'),
#    'latitude': Decimal128('51.077626')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18af6'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.176296'),
#    'latitude': Decimal128('51.078718')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18af7'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1762215'),
#    'latitude': Decimal128('51.0788531')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18af8'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.175897'),
#    'latitude': Decimal128('51.078513')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18af9'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.17535'),
#    'latitude': Decimal128('51.078033')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18afa'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17535'),
#    'latitude': Decimal128('51.078033')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18afb'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.17535'),
#    'latitude': Decimal128('51.078033')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18afc'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17535'),
#    'latitude': Decimal128('51.078033')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18afd'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.17535'),
#    'latitude': Decimal128('51.078033')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18afe'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.175811'),
#    'latitude': Decimal128('51.078515')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18aff'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.176258'),
#    'latitude': Decimal128('51.07879')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b00'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.175811'),
#    'latitude': Decimal128('51.078515')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b01'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.184803'),
#    'latitude': Decimal128('51.087382')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b02'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17591404914856'),
#    'latitude': Decimal128('51.0787391662598')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b03'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.189834'),
#    'latitude': Decimal128('51.09221')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b04'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17584'),
#    'latitude': Decimal128('51.07873')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b05'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17584'),
#    'latitude': Decimal128('51.07873')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b06'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.17584'),
#    'latitude': Decimal128('51.07873')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b07'),
#   'RatingValue': 1,
#   'geocode': {'longitude': Decimal128('1.17584'),
#    'latitude': Decimal128('51.07873')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b08'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.189833'),
#    'latitude': Decimal128('51.09221')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b09'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17841398715973'),
#    'latitude': Decimal128('51.0812644958496')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b0a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.172728'),
#    'latitude': Decimal128('51.076647')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b0b'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.172728'),
#    'latitude': Decimal128('51.076647')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b0c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.172728'),
#    'latitude': Decimal128('51.076647')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b0d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17725700019713'),
#    'latitude': Decimal128('51.0806630002457')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b0e'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.18431'),
#    'latitude': Decimal128('51.088115')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b0f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18431'),
#    'latitude': Decimal128('51.088115')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b10'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18431'),
#    'latitude': Decimal128('51.088115')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b11'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18431'),
#    'latitude': Decimal128('51.088115')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b12'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18431'),
#    'latitude': Decimal128('51.088115')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b13'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18431'),
#    'latitude': Decimal128('51.088115')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b14'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1748'),
#    'latitude': Decimal128('51.07856')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b15'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1842719'),
#    'latitude': Decimal128('51.0881644')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b16'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.172055'),
#    'latitude': Decimal128('51.076413')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b17'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.175782'),
#    'latitude': Decimal128('51.080171')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b18'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.174748'),
#    'latitude': Decimal128('51.079039')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b19'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.173056'),
#    'latitude': Decimal128('51.077492')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b1a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.175782'),
#    'latitude': Decimal128('51.080171')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b1b'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.17198'),
#    'latitude': Decimal128('51.076577')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b1c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.172652'),
#    'latitude': Decimal128('51.077414')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b1d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.172652'),
#    'latitude': Decimal128('51.077414')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b1e'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.17198'),
#    'latitude': Decimal128('51.076577')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b1f'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.185859'),
#    'latitude': Decimal128('51.090286')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b20'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.18468'),
#    'latitude': Decimal128('51.089337')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b21'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1784191'),
#    'latitude': Decimal128('51.0833323')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b22'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.172314'),
#    'latitude': Decimal128('51.077702')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b23'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.186289'),
#    'latitude': Decimal128('51.091129')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b24'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.16866'),
#    'latitude': Decimal128('51.074167')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b26'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.183925'),
#    'latitude': Decimal128('51.088333')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b27'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.172619'),
#    'latitude': Decimal128('51.078197')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b28'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.172619'),
#    'latitude': Decimal128('51.078197')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b29'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.172619'),
#    'latitude': Decimal128('51.078197')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b2a'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.172619'),
#    'latitude': Decimal128('51.078197')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b2b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.172619'),
#    'latitude': Decimal128('51.078197')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b2c'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.172619'),
#    'latitude': Decimal128('51.078197')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b2d'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.177367'),
#    'latitude': Decimal128('51.082871')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b2e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.173416'),
#    'latitude': Decimal128('51.079192')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b2f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.172619'),
#    'latitude': Decimal128('51.078197')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b30'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.172054'),
#    'latitude': Decimal128('51.078068')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b31'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.176219'),
#    'latitude': Decimal128('51.082381')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b32'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.172452'),
#    'latitude': Decimal128('51.078885')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b33'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.174678'),
#    'latitude': Decimal128('51.081154')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b34'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.169515'),
#    'latitude': Decimal128('51.07623')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b35'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.169515'),
#    'latitude': Decimal128('51.07623')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b36'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.168516'),
#    'latitude': Decimal128('51.075403')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b37'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.171552'),
#    'latitude': Decimal128('51.078874')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b38'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.172619'),
#    'latitude': Decimal128('51.078197')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b39'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.177755'),
#    'latitude': Decimal128('51.085001')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b3a'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.177729'),
#    'latitude': Decimal128('51.085038')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b3b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.177729'),
#    'latitude': Decimal128('51.085038')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b3c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.177729'),
#    'latitude': Decimal128('51.085038')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b3d'),
#   'RatingValue': 2,
#   'geocode': {'longitude': Decimal128('1.181507'),
#    'latitude': Decimal128('51.088893')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b3e'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.17363'),
#    'latitude': Decimal128('51.08129')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b3f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.173631'),
#    'latitude': Decimal128('51.081291')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b40'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.173631'),
#    'latitude': Decimal128('51.081291')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b41'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.168984'),
#    'latitude': Decimal128('51.077243')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b42'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.17373'),
#    'latitude': Decimal128('51.0819')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b43'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.178428'),
#    'latitude': Decimal128('51.086485')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b44'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.179997'),
#    'latitude': Decimal128('51.088124')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b45'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.179998'),
#    'latitude': Decimal128('51.088125')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b46'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.178766'),
#    'latitude': Decimal128('51.087034')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b47'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.178766'),
#    'latitude': Decimal128('51.087034')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18b48'),
#   'RatingValue': 5,
# ...
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.137589'),
#    'latitude': Decimal128('51.084261')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e1a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.401727'),
#    'latitude': Decimal128('51.338829')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e1b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.146772'),
#    'latitude': Decimal128('51.093315')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e1c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.401727'),
#    'latitude': Decimal128('51.338829')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e1d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.401727'),
#    'latitude': Decimal128('51.338829')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e1e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.430937'),
#    'latitude': Decimal128('51.366877')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e1f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.430937'),
#    'latitude': Decimal128('51.366877')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e20'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.43093705177307'),
#    'latitude': Decimal128('51.3668785095215')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e22'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.142092'),
#    'latitude': Decimal128('51.089168')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e23'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.407923'),
#    'latitude': Decimal128('51.345305')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e26'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.166913'),
#    'latitude': Decimal128('51.113576')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e27'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.135332'),
#    'latitude': Decimal128('51.083198')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e28'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.139687'),
#    'latitude': Decimal128('51.087407')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e29'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.431917'),
#    'latitude': Decimal128('51.368648')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e2a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.393021'),
#    'latitude': Decimal128('51.331795')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e2b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.410663'),
#    'latitude': Decimal128('51.348733')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e2c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.410663'),
#    'latitude': Decimal128('51.348733')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e2d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.39302098751068'),
#    'latitude': Decimal128('51.3317947387695')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e2f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.42510104179382'),
#    'latitude': Decimal128('51.3635864257812')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e30'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.433148'),
#    'latitude': Decimal128('51.371076')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e31'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.164273'),
#    'latitude': Decimal128('51.112388')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e32'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.142888'),
#    'latitude': Decimal128('51.091441')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e33'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('0.959720015525818'),
#    'latitude': Decimal128('50.9134254455566')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e34'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.422112'),
#    'latitude': Decimal128('51.360875')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e35'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.427302'),
#    'latitude': Decimal128('51.3663')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e36'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.14106'),
#    'latitude': Decimal128('51.091013')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e37'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.158123'),
#    'latitude': Decimal128('51.107275')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e38'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.444029'),
#    'latitude': Decimal128('51.381812')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e39'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.137347'),
#    'latitude': Decimal128('51.087434')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e3a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.40673'),
#    'latitude': Decimal128('51.346842')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e3b'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.1651994'),
#    'latitude': Decimal128('51.1150651')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e3c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1651994'),
#    'latitude': Decimal128('51.1150651')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e3e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.415953'),
#    'latitude': Decimal128('51.356504')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e3f'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.121041'),
#    'latitude': Decimal128('51.072229')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e40'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.121041'),
#    'latitude': Decimal128('51.072229')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e41'),
#   'RatingValue': 3,
#   'geocode': {'longitude': Decimal128('1.12104105949402'),
#    'latitude': Decimal128('51.0722274780273')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e42'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.161841'),
#    'latitude': Decimal128('51.11213')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e43'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.393792'),
#    'latitude': Decimal128('51.335425')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e47'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.160391'),
#    'latitude': Decimal128('51.110991')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e48'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.401173'),
#    'latitude': Decimal128('51.343189')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e49'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.401173'),
#    'latitude': Decimal128('51.343189')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e4a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.415595'),
#    'latitude': Decimal128('51.35691')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e4b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.138816'),
#    'latitude': Decimal128('51.090777')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e4c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('0.972863'),
#    'latitude': Decimal128('50.928769')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e4d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.418731'),
#    'latitude': Decimal128('51.359859')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e4e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.160391'),
#    'latitude': Decimal128('51.110991')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e4f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.164221'),
#    'latitude': Decimal128('51.115816')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e50'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.164222'),
#    'latitude': Decimal128('51.115817')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e51'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.164222'),
#    'latitude': Decimal128('51.115817')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e52'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('0.972863'),
#    'latitude': Decimal128('50.928769')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e53'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.164222'),
#    'latitude': Decimal128('51.115817')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e54'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.158654'),
#    'latitude': Decimal128('51.110454')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e55'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.140274'),
#    'latitude': Decimal128('51.092698')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e56'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.140274'),
#    'latitude': Decimal128('51.092698')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e57'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.439276'),
#    'latitude': Decimal128('51.38035')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e58'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.40902197360992'),
#    'latitude': Decimal128('51.3518028259277')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e59'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.413732'),
#    'latitude': Decimal128('51.356199')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e5a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.16437101364136'),
#    'latitude': Decimal128('51.1165313720703')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e5c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1191845'),
#    'latitude': Decimal128('51.0726696')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e5d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.160059'),
#    'latitude': Decimal128('51.112412')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e5e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.160059'),
#    'latitude': Decimal128('51.112412')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e5f'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.424766'),
#    'latitude': Decimal128('51.366986')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e60'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.4053856'),
#    'latitude': Decimal128('51.3485244')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e61'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.164371'),
#    'latitude': Decimal128('51.116532')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e62'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.3994987'),
#    'latitude': Decimal128('51.3429296')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e63'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.170369'),
#    'latitude': Decimal128('51.122522')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e64'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.418525'),
#    'latitude': Decimal128('51.360944')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e65'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.439561'),
#    'latitude': Decimal128('51.381088')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e66'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.118816'),
#    'latitude': Decimal128('51.072477')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e67'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.134991'),
#    'latitude': Decimal128('51.088298')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e68'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.134991'),
#    'latitude': Decimal128('51.088298')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e69'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.4107282'),
#    'latitude': Decimal128('51.3539278')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e6b'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.410985'),
#    'latitude': Decimal128('51.354229')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e6d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.399246'),
#    'latitude': Decimal128('51.343344')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e6e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.427116'),
#    'latitude': Decimal128('51.369967')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e6f'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.427116'),
#    'latitude': Decimal128('51.369967')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e70'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.4271160364151'),
#    'latitude': Decimal128('51.3699684143066')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e71'),
#   'RatingValue': None,
#   'geocode': {'longitude': Decimal128('1.43155097961426'),
#    'latitude': Decimal128('51.3743057250977')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e72'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.43155097961426'),
#    'latitude': Decimal128('51.3743057250977')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e73'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.431551'),
#    'latitude': Decimal128('51.374308')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e74'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.160059'),
#    'latitude': Decimal128('51.112412')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e75'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.134775'),
#    'latitude': Decimal128('51.088897')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e77'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.408037'),
#    'latitude': Decimal128('51.352702')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e78'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.434777'),
#    'latitude': Decimal128('51.377667')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e79'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.42351'),
#    'latitude': Decimal128('51.367482')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e7a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.42351'),
#    'latitude': Decimal128('51.367482')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e7b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.398588'),
#    'latitude': Decimal128('51.343957')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e7c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.398588'),
#    'latitude': Decimal128('51.343957')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e7d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.420118'),
#    'latitude': Decimal128('51.364585')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e7e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.434777'),
#    'latitude': Decimal128('51.377667')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e7f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1688388'),
#    'latitude': Decimal128('51.1230953')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e80'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.1688388'),
#    'latitude': Decimal128('51.1230953')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e82'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.426555'),
#    'latitude': Decimal128('51.370928')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e83'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.426555'),
#    'latitude': Decimal128('51.370928')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e84'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.39900100231171'),
#    'latitude': Decimal128('51.3446922302246')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e85'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.400038'),
#    'latitude': Decimal128('51.345885')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e86'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.420118'),
#    'latitude': Decimal128('51.364585')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e87'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.412458'),
#    'latitude': Decimal128('51.356848')}},
#  {'_id': ObjectId('65694a51cca46f7b69a18e88'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.422304'),
#    'latitude': Decimal128('51.367121')}},
#  ...]
